# %%
import pandas as pd

# %%
mayo = pd.read_excel("mayo clinic/mayo final.xlsx")
mayo
# Out:
#                                name                name2  \
# 0                             A fib  Atrial fibrillation
# 1         Abdominal aortic aneurysm                  NaN
# 2     Abnormally excessive sweating        Hyperhidrosis
# 3              Abscess, Bartholin's     Bartholin's cyst
# 4                   Absence seizure                  NaN
# ...                             ...                  ...
# 2188                Yersinia pestis               Plague
# 2189                           Yips                  NaN
# 2190                     Zika virus                  NaN
# 2191     Zollinger-Ellison syndrome                  NaN
# 2192                         Zoster             Shingles
#
#                                                    link  \
# 0     https://www.mayoclinic.org/diseases-conditions...
# 1     https://www.mayoclinic.org/diseases-conditions...
# 2     https://www.mayoclinic.org/diseases-conditions...
# ...

# %%
earthc = pd.read_csv("earthclinic/earthclinic_disease_data.csv")
earthc
# Out:
#                    disease                                               link  \
# 0      abdominal adhesions  https://www.earthclinic.com/cures/natural-reme...
# 1          abdominal fluid  https://www.earthclinic.com/cures/ascites-abdo...
# 2           abdominal pain  https://www.earthclinic.com/cures/stomach-pain...
# 3     acanthosis nigricans  https://www.earthclinic.com/cures/acanthosis-n...
# 4      achilles tendonitis  https://www.earthclinic.com/cures/natural-trea...
# ...                    ...                                                ...
# 1260                 worms   https://www.earthclinic.com/cures/parasites.html
# 1261                wounds        https://www.earthclinic.com/cures/cuts.html
# 1262    xanthelasma polyps  https://www.earthclinic.com/cures/xanthelasma-...
# 1263              xanthoma    https://www.earthclinic.com/cures/xanthoma.html
# 1264      yeast infections  https://www.earthclinic.com/cures/yeast_infect...
#
# ...

# %%
medi = pd.read_excel("medindia/medindia final.xlsx")
medi
# Out:
#                     name                                               link  \
# 0    Acid Reflux Disease  https://www.medindia.net/homeremedies/acid-ref...
# 1                Acidity  https://www.medindia.net/homeremedies/acidity.asp
# 2                   Acne     https://www.medindia.net/homeremedies/acne.asp
# 3              Age Spots  https://www.medindia.net/homeremedies/age-spot...
# 4             Alcoholism  https://www.medindia.net/homeremedies/alcoholi...
# ..                   ...                                                ...
# 118          Weak Memory  https://www.medindia.net/homeremedies/weakmemo...
# 119          Weight Loss  https://www.medindia.net/homeremedies/weight-l...
# 120          White Teeth  https://www.medindia.net/homeremedies/white-te...
# 121           Whiteheads  https://www.medindia.net/homeremedies/whitehea...
# 122     Yeast Infections  https://www.medindia.net/homeremedies/yeast-in...
#
#                                                   data
# ...

# %%
with pd.ExcelWriter('output.xlsx') as writer:  
    mayo.to_excel(writer, sheet_name='mayo')
    earthc.to_excel(writer, sheet_name='earthclinic')
    medi.to_excel(writer, sheet_name='medindia')
